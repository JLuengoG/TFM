# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ruta = '/content/drive/MyDrive/TFM/Google_Colab/TFM_dataset_imagenes/Datasets/Fourierv2'

# %% [markdown]
# # Import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import keras
from keras.datasets import fashion_mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping, Callback, ModelCheckpoint
from sklearn.utils import shuffle
from keras.models import load_model

import tensorflow as tf

from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam

from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Def

# %%
def mean(data, no_elements):  # Toma dos argumentos: un conjunto de datos y un número de elementos.
    X = np.zeros((data.shape[0], data.shape[1]))  # Creamos una matriz de ceros con la misma forma que los datos de entrada.
    for i in range(data.shape[1] - no_elements + 1):  # En las últimas filas no se calcula la media, quedaran no_elements -1 filas de ceros al final
        X[:, i] = np.mean(data[:, i:i + no_elements], axis=1)  # asignamos a la columna i-ésima de X la media de la submatriz de los datos que va desde la columna i hasta la columna i + no_elements, a lo largo del eje 1 (columnas).
    return X.astype(np.float16)  # Finalmente, convertimos los valores en la matriz X a float16 para ahorrar memoria y la retornamos.

def median(data, no_elements):
    X = np.zeros((data.shape[0], data.shape[1]))
    for i in range(data.shape[1] - no_elements + 1):
        X[:, i] = np.median(data[:, i:i + no_elements], axis=1)
    return X.astype(np.float16)

def sig_image(data, size):  # Toma dos argumentos: un conjunto de datos y un tamaño.
    X = np.zeros((data.shape[0], size, size))  # Creamos una matriz de ceros con la forma especificada: número de filas en los datos y tamaño dado al cuadrado.
    for i in range(data.shape[0]):  # Para cada índice desde 0 hasta el número de filas en los datos,
        X[i] = (data[i, :].reshape(size, size))  # asignamos a la i-ésima entrada de X los datos en la fila i, reorganizados como una matriz de tamaño size x size.
    return X.astype(np.float16)  # Finalmente, convertimos los valores en la matriz X a float16 para ahorrar memoria y la retornamos.

def convertir_a_imagenes(dataset):
    channel_mean = (mean(dataset, 10)).astype(np.float16)
    # Esto calculará la media en ventanas de tamaño 10 a lo largo de cada columna en 'x'.

    x_mean = sig_image(channel_mean, 40)
    # Esta función remodelará cada fila en 'channel_mean' en una imagen de 40x40.

    channel_median = (median(dataset, 10)).astype(np.float16)
    # Esto calculará la mediana en ventanas de tamaño 10 a lo largo de cada columna en 'x'.

    x_md = sig_image(dataset, 40)
    # Esta función remodelará cada fila en 'x' en una imagen de 40x40.

    x_n=sig_image(dataset,40)

    # np.stack() en Numpy se utiliza para unir un secuencia de arrays a lo largo de un nuevo eje.
    X=np.stack((x_n,x_mean,x_md),axis=1).astype(np.float16)

    # En Keras, los canales van al final
    X = X.transpose(0, 2, 3, 1)

    return X

# %%
def entrenamiento_grafica(x, y, x_test, y_test, n_test, patience):

  epochs = 200
  metrica_parar = 'val_accuracy'

  x_train, x_train_val, y_train, y_train_val = train_test_split(x, y, test_size=0.2, random_state=20)
  print(f'x_train = {x_train.shape}')
  print(f'x_train_val = {x_train_val.shape}')

  x_test_shuffle, y_test_shuffle = shuffle(x_test, y_test, random_state=42)
  x_test = x_test_shuffle[:n_test]
  y_test = y_test_shuffle[:n_test]


  #Callbacks
  patience = patience

  # EarlyStop si durante 10 epoch no se consigue ninguna mejora en accuracy
  early_stopping = EarlyStopping(monitor=metrica_parar, patience=patience)

  #Imprimir mensaje indicando que no se han conseguido mejoras durante 10 epoch.
  class ImprimirMensajeCallback(Callback):
      def on_train_begin(self, logs=None):
          self.stopped_epoch = 0

      def on_epoch_end(self, epoch, logs=None):
          if self.model.stop_training:
             self.stopped_epoch = epoch
             print(f"El entrenamiento ha sido detenido en el epoch {self.stopped_epoch + 1}. {metrica_parar} no ha mejorado durante {patience} epoch.")


  # Creación del modelo
  model = Sequential()
  model.add(Conv2D(32, kernel_size=(4, 4), strides=(1, 1), padding='same', activation='relu', input_shape=(40, 40, 3)))
  model.add(MaxPooling2D(pool_size=(4, 4), strides=(2, 2)))
  model.add(Conv2D(64, kernel_size=(4, 4), strides=(1, 1), activation='relu'))
  model.add(MaxPooling2D(pool_size=(4, 4), strides=(2, 2)))
  model.add(Flatten())
  model.add(Dense(256, activation='relu'))
  model.add(Dropout(0.2))
  model.add(Dense(10, activation='softmax'))

  # Compilación del modelo
  model.compile(optimizer=Adam(learning_rate=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

  mi_callback = ImprimirMensajeCallback()

  # ModelCheckpoint para guardar el mejor modelo
  checkpoint = ModelCheckpoint(
      'modelos/mejor_modelo.h5',  # Ruta relativa al archivo
      monitor=metrica_parar,
      save_best_only=True,
      mode='max',
      verbose=0
  )

  # Entrenamiento del modelo
  history = model.fit(x_train, y_train, batch_size=128, epochs=epochs, verbose=1, validation_data=(x_train_val, y_train_val), callbacks=[early_stopping, mi_callback, checkpoint])

  epoch_donde_se_detuvo = mi_callback.stopped_epoch

  # Crear una gráfica con los datos del DataFrame
  pd.DataFrame(history.history).plot(
    figsize=(10,5),   # Tamaño de la gráfica
    xlim=[0,epoch_donde_se_detuvo],     # Límites del eje X
    ylim=[0,1.5],      # Límites del eje Y
    grid=True,       # Mostrar cuadrícula en la gráfica
    xlabel='Epoch',  # Etiqueta del eje X
    style=['r--','r-']  # Estilo de línea de cada columna
  )
  # Mostrar la gráfica
  ####################
  plt.show()

  # print('********************')
  # acc = history.history['accuracy']
  # ult_acc = acc[-patience-1:]
  # print('Train accuracy: ', ult_acc)

  # loss = history.history['loss']
  # ult_loss = loss[-patience-1:]
  # print('Train loss: ', ult_loss)

  # Test
  ######

  # Cargar el mejor modelo guardado
  mejor_modelo = load_model('modelos/mejor_modelo.h5')

  print('*********TEST**********')
  print(f'Nº de muestras para el test: {x_test.shape}')
  test_loss, test_acc = mejor_modelo.evaluate(x_test, y_test, verbose=0)
  print('Resultados del test:')
  print('\nTest accuracy:', test_acc)
  print('Test loss:', test_loss)

  # Obtener las predicciones del modelo en el conjunto de prueba
  y_pred = model.predict(x_test)
  y_pred_labels = np.argmax(y_pred, axis=1)  # Obtener las etiquetas predichas

  # Calcular la matriz de confusión
  conf_matrix = confusion_matrix(y_test, y_pred_labels)

  # Crear una figura para la matriz de confusión
  plt.figure(figsize=(8, 6))
  sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
  plt.title('Matriz de Confusión')
  plt.xlabel('Etiqueta Predicha')
  plt.ylabel('Etiqueta Real')
  plt.show()

  # Calcular los porcentajes de acierto por etiqueta
  row_sums = conf_matrix.sum(axis=1, keepdims=True)
  conf_matrix_percent = conf_matrix / row_sums

  # Crear una figura para la matriz de confusión
  plt.figure(figsize=(8, 6))
  sns.heatmap(conf_matrix_percent, annot=True, fmt='.2%', cmap='Blues', cbar=False)
  plt.title('Matriz de Confusión (Porcentaje de Acierto)')
  plt.xlabel('Etiqueta Predicha')
  plt.ylabel('Etiqueta Real')
  plt.show()

# %%
# Train
def entrenamiento(x_train, y_train, x_test, y_test, n_test, patience):
  x_train_3D = convertir_a_imagenes(x_train)
  print(f'x_train_3D matriz = {x_train_3D.shape}')

  # Test
  x_test_3D = convertir_a_imagenes(x_test)
  print(f'x_test_3D matriz = {x_test_3D.shape}')

  # Entrenamiento
  ###############
  entrenamiento_grafica(x_train_3D, y_train, x_test_3D, y_test, n_test, patience)

# %% [markdown]
# # Entrenamiento

# %% [markdown]
# ## Fourierv2

# %%
x_train =np.load(f'{ruta}/x_train_Fourierv2.npy')
y_train =np.load(f'{ruta}/y_train_Fourierv2.npy')

x_test = np.load(f'{ruta}/x_test_Fourierv2.npy')
y_test = np.load(f'{ruta}/y_test_Fourierv2.npy')

entrenamiento(x_train, y_train, x_test, y_test, 400, 20)
# Out:
# x_train_3D matriz = (2240, 40, 40, 3)
# x_test_3D matriz = (560, 40, 40, 3)
# x_train = (1792, 40, 40, 3)
# x_train_val = (448, 40, 40, 3)
# Epoch 1/200
#  6/14 [===========>..................] - ETA: 0s - loss: 28.6197 - accuracy: 0.1536
# WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0096s vs `on_train_batch_end` time: 0.0121s). Check your callbacks.
# 14/14 [==============================] - 10s 183ms/step - loss: 14.9727 - accuracy: 0.2360 - val_loss: 1.7400 - val_accuracy: 0.3661
# Epoch 2/200
# 14/14 [==============================] - 1s 48ms/step - loss: 1.5478 - accuracy: 0.5346 - val_loss: 1.1685 - val_accuracy: 0.6116
# Epoch 3/200
# 14/14 [==============================] - 1s 46ms/step - loss: 0.8788 - accuracy: 0.7260 - val_loss: 0.6013 - val_accuracy: 0.8371
# Epoch 4/200
# 14/14 [==============================] - 0s 32ms/step - loss: 0.4909 - accuracy: 0.8544 - val_loss: 0.3516 - val_accuracy: 0.9018
# Epoch 5/200
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3320 - accuracy: 0.8839 - val_loss: 0.2580 - val_accuracy: 0.9241
# Epoch 6/200
# 14/14 [==============================] - 0s 28ms/step - loss: 0.2253 - accuracy: 0.9235 - val_loss: 0.2365 - val_accuracy: 0.9107
# Epoch 7/200
# 14/14 [==============================] - 0s 28ms/step - loss: 0.2069 - accuracy: 0.9353 - val_loss: 0.2415 - val_accuracy: 0.9241
# Epoch 8/200
# 14/14 [==============================] - 0s 32ms/step - loss: 0.1327 - accuracy: 0.9515 - val_loss: 0.1764 - val_accuracy: 0.9330
# Epoch 9/200
# 14/14 [==============================] - 0s 33ms/step - loss: 0.1039 - accuracy: 0.9693 - val_loss: 0.1227 - val_accuracy: 0.9598
# Epoch 10/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0912 - accuracy: 0.9715 - val_loss: 0.1327 - val_accuracy: 0.9643
# Epoch 11/200
# 14/14 [==============================] - 0s 30ms/step - loss: 0.0764 - accuracy: 0.9782 - val_loss: 0.0838 - val_accuracy: 0.9777
# Epoch 12/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0643 - accuracy: 0.9844 - val_loss: 0.1532 - val_accuracy: 0.9643
# Epoch 13/200
# 14/14 [==============================] - 0s 25ms/step - loss: 0.0666 - accuracy: 0.9771 - val_loss: 0.1086 - val_accuracy: 0.9665
# Epoch 14/200
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0831 - accuracy: 0.9710 - val_loss: 0.0979 - val_accuracy: 0.9688
# Epoch 15/200
# 14/14 [==============================] - 0s 21ms/step - loss: 0.0697 - accuracy: 0.9821 - val_loss: 0.0791 - val_accuracy: 0.9777
# Epoch 16/200
# 14/14 [==============================] - 0s 20ms/step - loss: 0.0589 - accuracy: 0.9821 - val_loss: 0.0935 - val_accuracy: 0.9754
# Epoch 17/200
# 14/14 [==============================] - 0s 33ms/step - loss: 0.0417 - accuracy: 0.9877 - val_loss: 0.0421 - val_accuracy: 0.9866
# Epoch 18/200
# 14/14 [==============================] - 0s 23ms/step - loss: 0.0299 - accuracy: 0.9950 - val_loss: 0.0677 - val_accuracy: 0.9799
# Epoch 19/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0209 - accuracy: 0.9961 - val_loss: 0.0836 - val_accuracy: 0.9821
# Epoch 20/200
# 14/14 [==============================] - 0s 19ms/step - loss: 0.0237 - accuracy: 0.9950 - val_loss: 0.0623 - val_accuracy: 0.9799
# Epoch 21/200
# 14/14 [==============================] - 0s 24ms/step - loss: 0.0195 - accuracy: 0.9939 - val_loss: 0.0705 - val_accuracy: 0.9844
# Epoch 22/200
# 14/14 [==============================] - 1s 36ms/step - loss: 0.0173 - accuracy: 0.9967 - val_loss: 0.0700 - val_accuracy: 0.9911
# Epoch 23/200
# 14/14 [==============================] - 0s 31ms/step - loss: 0.0136 - accuracy: 0.9967 - val_loss: 0.0686 - val_accuracy: 0.9866
# Epoch 24/200
# 14/14 [==============================] - 0s 28ms/step - loss: 0.0125 - accuracy: 0.9972 - val_loss: 0.0810 - val_accuracy: 0.9888
# Epoch 25/200
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0131 - accuracy: 0.9961 - val_loss: 0.0672 - val_accuracy: 0.9844
# Epoch 26/200
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0084 - accuracy: 0.9994 - val_loss: 0.0567 - val_accuracy: 0.9799
# Epoch 27/200
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0078 - accuracy: 0.9989 - val_loss: 0.0649 - val_accuracy: 0.9799
# Epoch 28/200
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0129 - accuracy: 0.9978 - val_loss: 0.0655 - val_accuracy: 0.9866
# Epoch 29/200
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0092 - accuracy: 0.9972 - val_loss: 0.0638 - val_accuracy: 0.9866
# Epoch 30/200
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0119 - accuracy: 0.9989 - val_loss: 0.0863 - val_accuracy: 0.9799
# Epoch 31/200
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0345 - accuracy: 0.9911 - val_loss: 0.0623 - val_accuracy: 0.9754
# Epoch 32/200
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0385 - accuracy: 0.9855 - val_loss: 0.1622 - val_accuracy: 0.9643
# Epoch 33/200
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0263 - accuracy: 0.9916 - val_loss: 0.0702 - val_accuracy: 0.9844
# Epoch 34/200
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0093 - accuracy: 0.9978 - val_loss: 0.0896 - val_accuracy: 0.9821
# Epoch 35/200
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0136 - accuracy: 0.9961 - val_loss: 0.0599 - val_accuracy: 0.9911
# Epoch 36/200
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0063 - accuracy: 0.9989 - val_loss: 0.0930 - val_accuracy: 0.9777
# Epoch 37/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0092 - accuracy: 0.9983 - val_loss: 0.0921 - val_accuracy: 0.9777
# Epoch 38/200
# 14/14 [==============================] - 0s 14ms/step - loss: 0.0095 - accuracy: 0.9972 - val_loss: 0.0677 - val_accuracy: 0.9777
# Epoch 39/200
# 14/14 [==============================] - 0s 18ms/step - loss: 0.0077 - accuracy: 0.9994 - val_loss: 0.0789 - val_accuracy: 0.9844
# Epoch 40/200
# 14/14 [==============================] - 0s 17ms/step - loss: 0.0056 - accuracy: 0.9983 - val_loss: 0.0599 - val_accuracy: 0.9866
# Epoch 41/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0040 - accuracy: 0.9989 - val_loss: 0.0850 - val_accuracy: 0.9844
# Epoch 42/200
# 11/14 [======================>.......] - ETA: 0s - loss: 0.0029 - accuracy: 1.0000El entrenamiento ha sido detenido en el epoch 42. Loss no ha mejorado durante 20 epoch.
# 14/14 [==============================] - 0s 15ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0521 - val_accuracy: 0.9844
# *********TEST**********
# Nº de muestras para el test: (400, 40, 40, 3)
# Resultados del test:
#
# Test accuracy: 0.9950000047683716
# Test loss: 0.029318852350115776
# 13/13 [==============================] - 0s 3ms/step

# %% [markdown]
# ## originalv2 Desbalanceado 50

# %%
x_train =np.load(f'{ruta}/x_train_Fourierv2_desbalanceado50.npy')
y_train =np.load(f'{ruta}/y_train_Fourierv2_desbalanceado50.npy')

x_test = np.load(f'{ruta}/x_test_Fourierv2.npy')
y_test = np.load(f'{ruta}/y_test_Fourierv2.npy')

entrenamiento(x_train, y_train, x_test, y_test, 400, 20)
# Out:
# x_train_3D matriz = (650, 40, 40, 3)
# x_test_3D matriz = (560, 40, 40, 3)
# x_train = (520, 40, 40, 3)
# x_train_val = (130, 40, 40, 3)
# Epoch 1/200
# 5/5 [==============================] - 3s 168ms/step - loss: 33.5836 - accuracy: 0.1058 - val_loss: 4.1234 - val_accuracy: 0.5692
# Epoch 2/200
# 5/5 [==============================] - 0s 44ms/step - loss: 3.9309 - accuracy: 0.5000 - val_loss: 1.6882 - val_accuracy: 0.5769
# Epoch 3/200
# 5/5 [==============================] - 0s 33ms/step - loss: 1.6786 - accuracy: 0.5654 - val_loss: 1.1931 - val_accuracy: 0.6615
# Epoch 4/200
# 5/5 [==============================] - 0s 39ms/step - loss: 1.1122 - accuracy: 0.6692 - val_loss: 0.8959 - val_accuracy: 0.7154
# Epoch 5/200
# 5/5 [==============================] - 0s 39ms/step - loss: 0.7304 - accuracy: 0.7654 - val_loss: 0.6104 - val_accuracy: 0.8308
# Epoch 6/200
# 5/5 [==============================] - 0s 37ms/step - loss: 0.5151 - accuracy: 0.8346 - val_loss: 0.4622 - val_accuracy: 0.8692
# Epoch 7/200
# 5/5 [==============================] - 0s 40ms/step - loss: 0.3884 - accuracy: 0.8731 - val_loss: 0.5065 - val_accuracy: 0.9154
# Epoch 8/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.4644 - accuracy: 0.8635 - val_loss: 0.3670 - val_accuracy: 0.8769
# Epoch 9/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3150 - accuracy: 0.9000 - val_loss: 0.3675 - val_accuracy: 0.9000
# Epoch 10/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.3434 - accuracy: 0.8673 - val_loss: 0.2993 - val_accuracy: 0.9077
# Epoch 11/200
# 5/5 [==============================] - 0s 44ms/step - loss: 0.2376 - accuracy: 0.9077 - val_loss: 0.2315 - val_accuracy: 0.9385
# Epoch 12/200
# 5/5 [==============================] - 0s 25ms/step - loss: 0.2184 - accuracy: 0.9269 - val_loss: 0.2126 - val_accuracy: 0.9385
# Epoch 13/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.2139 - accuracy: 0.9365 - val_loss: 0.2101 - val_accuracy: 0.9385
# Epoch 14/200
# 5/5 [==============================] - 0s 19ms/step - loss: 0.1751 - accuracy: 0.9462 - val_loss: 0.2298 - val_accuracy: 0.9154
# Epoch 15/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.5488 - accuracy: 0.8462 - val_loss: 0.5696 - val_accuracy: 0.8000
# Epoch 16/200
# 5/5 [==============================] - 0s 17ms/step - loss: 0.4579 - accuracy: 0.8481 - val_loss: 0.4177 - val_accuracy: 0.8769
# Epoch 17/200
# 5/5 [==============================] - 0s 22ms/step - loss: 0.2523 - accuracy: 0.9212 - val_loss: 0.2836 - val_accuracy: 0.9154
# Epoch 18/200
# 5/5 [==============================] - 0s 27ms/step - loss: 0.2435 - accuracy: 0.9231 - val_loss: 0.1869 - val_accuracy: 0.9538
# Epoch 19/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.1498 - accuracy: 0.9596 - val_loss: 0.1940 - val_accuracy: 0.9385
# Epoch 20/200
# 5/5 [==============================] - 0s 31ms/step - loss: 0.1301 - accuracy: 0.9500 - val_loss: 0.1244 - val_accuracy: 0.9692
# Epoch 21/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.1462 - accuracy: 0.9462 - val_loss: 0.1175 - val_accuracy: 0.9615
# Epoch 22/200
# 5/5 [==============================] - 0s 29ms/step - loss: 0.1147 - accuracy: 0.9712 - val_loss: 0.1380 - val_accuracy: 0.9769
# Epoch 23/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.1025 - accuracy: 0.9692 - val_loss: 0.1787 - val_accuracy: 0.9538
# Epoch 24/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.1231 - accuracy: 0.9577 - val_loss: 0.0988 - val_accuracy: 0.9692
# Epoch 25/200
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0693 - accuracy: 0.9904 - val_loss: 0.0918 - val_accuracy: 0.9615
# Epoch 26/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0710 - accuracy: 0.9750 - val_loss: 0.1057 - val_accuracy: 0.9692
# Epoch 27/200
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0645 - accuracy: 0.9827 - val_loss: 0.0960 - val_accuracy: 0.9615
# Epoch 28/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0724 - accuracy: 0.9827 - val_loss: 0.0855 - val_accuracy: 0.9692
# Epoch 29/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0456 - accuracy: 0.9885 - val_loss: 0.0793 - val_accuracy: 0.9692
# Epoch 30/200
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0373 - accuracy: 0.9885 - val_loss: 0.0563 - val_accuracy: 0.9846
# Epoch 31/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0415 - accuracy: 0.9885 - val_loss: 0.0810 - val_accuracy: 0.9769
# Epoch 32/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0268 - accuracy: 0.9942 - val_loss: 0.0705 - val_accuracy: 0.9692
# Epoch 33/200
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0266 - accuracy: 0.9942 - val_loss: 0.0517 - val_accuracy: 0.9692
# Epoch 34/200
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0312 - accuracy: 0.9885 - val_loss: 0.0677 - val_accuracy: 0.9692
# Epoch 35/200
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0280 - accuracy: 0.9923 - val_loss: 0.0738 - val_accuracy: 0.9692
# Epoch 36/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0407 - accuracy: 0.9865 - val_loss: 0.0735 - val_accuracy: 0.9692
# Epoch 37/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0380 - accuracy: 0.9846 - val_loss: 0.0802 - val_accuracy: 0.9692
# Epoch 38/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0281 - accuracy: 0.9962 - val_loss: 0.0892 - val_accuracy: 0.9692
# Epoch 39/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0359 - accuracy: 0.9904 - val_loss: 0.0884 - val_accuracy: 0.9615
# Epoch 40/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0490 - accuracy: 0.9885 - val_loss: 0.0886 - val_accuracy: 0.9538
# Epoch 41/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0366 - accuracy: 0.9923 - val_loss: 0.1112 - val_accuracy: 0.9615
# Epoch 42/200
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0181 - accuracy: 0.9962 - val_loss: 0.0688 - val_accuracy: 0.9692
# Epoch 43/200
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0196 - accuracy: 0.9962 - val_loss: 0.0507 - val_accuracy: 0.9769
# Epoch 44/200
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0200 - accuracy: 0.9942 - val_loss: 0.0915 - val_accuracy: 0.9615
# Epoch 45/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0178 - accuracy: 0.9981 - val_loss: 0.0676 - val_accuracy: 0.9692
# Epoch 46/200
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0150 - accuracy: 0.9962 - val_loss: 0.0480 - val_accuracy: 0.9769
# Epoch 47/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0213 - accuracy: 0.9942 - val_loss: 0.0565 - val_accuracy: 0.9692
# Epoch 48/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.1055 - val_accuracy: 0.9692
# Epoch 49/200
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0374 - accuracy: 0.9865 - val_loss: 0.0596 - val_accuracy: 0.9692
# Epoch 50/200
# 1/5 [=====>........................] - ETA: 0s - loss: 0.0065 - accuracy: 1.0000El entrenamiento ha sido detenido en el epoch 50. Loss no ha mejorado durante 20 epoch.
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.0838 - val_accuracy: 0.9769
# *********TEST**********
# Nº de muestras para el test: (400, 40, 40, 3)
# Resultados del test:
#
# Test accuracy: 0.9574999809265137
# Test loss: 0.1510974019765854
# 13/13 [==============================] - 0s 2ms/step

# %% [markdown]
# ## Originalv2 DATASET DCGAN

# %%
x_train =np.load(f'{ruta}/x_train_generado_150.npy')
y_train =np.load(f'{ruta}/y_train_generado_150.npy')

x_test = np.load(f'{ruta}/x_test_Fourierv2.npy')
y_test = np.load(f'{ruta}/y_test_Fourierv2.npy')

entrenamiento(x_train, y_train, x_test, y_test, 400, 20)
# Out:
# x_train_3D matriz = (2000, 40, 40, 3)
# x_test_3D matriz = (560, 40, 40, 3)
# x_train = (1600, 40, 40, 3)
# x_train_val = (400, 40, 40, 3)
# Epoch 1/200
# 13/13 [==============================] - 2s 32ms/step - loss: 11.8420 - accuracy: 0.3094 - val_loss: 1.2539 - val_accuracy: 0.6400
# Epoch 2/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.8546 - accuracy: 0.8019 - val_loss: 0.3629 - val_accuracy: 0.9350
# Epoch 3/200
# 13/13 [==============================] - 0s 19ms/step - loss: 0.2779 - accuracy: 0.9312 - val_loss: 0.1662 - val_accuracy: 0.9525
# Epoch 4/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.1698 - accuracy: 0.9481 - val_loss: 0.1145 - val_accuracy: 0.9625
# Epoch 5/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.1295 - accuracy: 0.9594 - val_loss: 0.1091 - val_accuracy: 0.9625
# Epoch 6/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0899 - accuracy: 0.9681 - val_loss: 0.0823 - val_accuracy: 0.9575
# Epoch 7/200
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0929 - accuracy: 0.9594 - val_loss: 0.0914 - val_accuracy: 0.9500
# Epoch 8/200
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0675 - accuracy: 0.9756 - val_loss: 0.1064 - val_accuracy: 0.9500
# Epoch 9/200
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0704 - accuracy: 0.9694 - val_loss: 0.1067 - val_accuracy: 0.9500
# Epoch 10/200
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0675 - accuracy: 0.9725 - val_loss: 0.0923 - val_accuracy: 0.9525
# Epoch 11/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0702 - accuracy: 0.9719 - val_loss: 0.0910 - val_accuracy: 0.9475
# Epoch 12/200
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0589 - accuracy: 0.9737 - val_loss: 0.0914 - val_accuracy: 0.9525
# Epoch 13/200
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0552 - accuracy: 0.9750 - val_loss: 0.0873 - val_accuracy: 0.9450
# Epoch 14/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0470 - accuracy: 0.9787 - val_loss: 0.0883 - val_accuracy: 0.9450
# Epoch 15/200
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0493 - accuracy: 0.9719 - val_loss: 0.0943 - val_accuracy: 0.9500
# Epoch 16/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0491 - accuracy: 0.9744 - val_loss: 0.0936 - val_accuracy: 0.9450
# Epoch 17/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0404 - accuracy: 0.9825 - val_loss: 0.1004 - val_accuracy: 0.9475
# Epoch 18/200
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0560 - accuracy: 0.9725 - val_loss: 0.0945 - val_accuracy: 0.9450
# Epoch 19/200
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0443 - accuracy: 0.9837 - val_loss: 0.1097 - val_accuracy: 0.9425
# Epoch 20/200
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0475 - accuracy: 0.9756 - val_loss: 0.1046 - val_accuracy: 0.9400
# Epoch 21/200
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0594 - accuracy: 0.9712 - val_loss: 0.0990 - val_accuracy: 0.9400
# Epoch 22/200
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0534 - accuracy: 0.9756 - val_loss: 0.1079 - val_accuracy: 0.9350
# Epoch 23/200
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0454 - accuracy: 0.9750 - val_loss: 0.0958 - val_accuracy: 0.9400
# Epoch 24/200
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0367 - accuracy: 0.9805El entrenamiento ha sido detenido en el epoch 24. Loss no ha mejorado durante 20 epoch.
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0366 - accuracy: 0.9806 - val_loss: 0.1047 - val_accuracy: 0.9475
# *********TEST**********
# Nº de muestras para el test: (400, 40, 40, 3)
# Resultados del test:
#
# Test accuracy: 0.8725000023841858
# Test loss: 0.4600023031234741
# 13/13 [==============================] - 0s 2ms/step
