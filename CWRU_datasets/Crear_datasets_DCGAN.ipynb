# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Cargar datos

# %%
# label 0
label0_200filas = np.load('/content/drive/MyDrive/TFM/Google_Colab/CWRU/CRWU_Javi/x_train_fourier_desbalanceado/x_train_fourier_label0_200filas.npy')

# label 1
label1_20filas = np.load('/content/drive/MyDrive/TFM/Google_Colab/CWRU/CRWU_Javi/x_train_fourier_desbalanceado/x_train_fourier_label1_20filas.npy')
gen1 = np.load('/content/drive/MyDrive/TFM/Google_Colab/CWRU/CRWU_Javi/CRWU_DCGAN/series_generadas_label1.npy')

# label 2
label2_20filas = np.load('/content/drive/MyDrive/TFM/Google_Colab/CWRU/CRWU_Javi/x_train_fourier_desbalanceado/x_train_fourier_label2_20filas.npy')
gen2 = np.load('/content/drive/MyDrive/TFM/Google_Colab/CWRU/CRWU_Javi/CRWU_DCGAN/series_generadas_label2.npy')

# label 3
label3_20filas = np.load('/content/drive/MyDrive/TFM/Google_Colab/CWRU/CRWU_Javi/x_train_fourier_desbalanceado/x_train_fourier_label3_20filas.npy')
gen3 = np.load('/content/drive/MyDrive/TFM/Google_Colab/CWRU/CRWU_Javi/CRWU_DCGAN/series_generadas_label3.npy')

# label 4
label4_20filas = np.load('/content/drive/MyDrive/TFM/Google_Colab/CWRU/CRWU_Javi/x_train_fourier_desbalanceado/x_train_fourier_label4_20filas.npy')
gen4 = np.load('/content/drive/MyDrive/TFM/Google_Colab/CWRU/CRWU_Javi/CRWU_DCGAN/series_generadas_label4.npy')

# label 5
label5_20filas = np.load('/content/drive/MyDrive/TFM/Google_Colab/CWRU/CRWU_Javi/x_train_fourier_desbalanceado/x_train_fourier_label5_20filas.npy')
gen5 = np.load('/content/drive/MyDrive/TFM/Google_Colab/CWRU/CRWU_Javi/CRWU_DCGAN/series_generadas_label5.npy')

# label 6
label6_20filas = np.load('/content/drive/MyDrive/TFM/Google_Colab/CWRU/CRWU_Javi/x_train_fourier_desbalanceado/x_train_fourier_label6_20filas.npy')
gen6 = np.load('/content/drive/MyDrive/TFM/Google_Colab/CWRU/CRWU_Javi/CRWU_DCGAN/series_generadas_label6.npy')

# label 7
label7_20filas = np.load('/content/drive/MyDrive/TFM/Google_Colab/CWRU/CRWU_Javi/x_train_fourier_desbalanceado/x_train_fourier_label7_20filas.npy')
gen7 = np.load('/content/drive/MyDrive/TFM/Google_Colab/CWRU/CRWU_Javi/CRWU_DCGAN/series_generadas_label7.npy')

# label 8
label8_20filas = np.load('/content/drive/MyDrive/TFM/Google_Colab/CWRU/CRWU_Javi/x_train_fourier_desbalanceado/x_train_fourier_label8_20filas.npy')
gen8 = np.load('/content/drive/MyDrive/TFM/Google_Colab/CWRU/CRWU_Javi/CRWU_DCGAN/series_generadas_label8.npy')

# label 9
label9_20filas = np.load('/content/drive/MyDrive/TFM/Google_Colab/CWRU/CRWU_Javi/x_train_fourier_desbalanceado/x_train_fourier_label9_20filas.npy')
gen9 = np.load('/content/drive/MyDrive/TFM/Google_Colab/CWRU/CRWU_Javi/CRWU_DCGAN/series_generadas_label9.npy')

# %%
filas= 5
gen1_filas = gen1[:filas]
gen2_filas = gen2[:filas]
gen3_filas = gen3[:filas]
gen4_filas = gen4[:filas]
gen5_filas = gen5[:filas]
gen6_filas = gen6[:filas]
gen7_filas = gen7[:filas]
gen8_filas = gen8[:filas]
gen9_filas = gen9[:filas]

# %%
label1_20filas.shape
label0_200filas.shape
# Out:
# (200, 1600)

# %%
dataset = []
dataset = np.concatenate((label0_200filas,
                          label1_20filas, gen1_filas,
                          label2_20filas, gen2_filas,
                          label2_20filas, gen3_filas,
                          label4_20filas, gen4_filas,
                          label5_20filas, gen5_filas,
                          label6_20filas, gen6_filas,
                          label7_20filas, gen7_filas,
                          label8_20filas, gen8_filas,
                          label9_20filas, gen9_filas
                        ), axis=0)

# %%
dataset.shape
# Out:
# (425, 1600)

# %%
np.save(f'/content/drive/MyDrive/TFM/Google_Colab/CWRU/CRWU_Javi/datasets_finales/dataset_{filas}', dataset)

# %% [markdown]
# # LABELS

# %%
np_labels = np.array(0)
for label in list(range(0,10)):
  if label == 0:
    # Crear array con las etiquetas
    np_labels = np.zeros(200)
  else:
    np_nlabels_1 = np.full(20, label)
    np_nlabels_2 = np.full(filas, label)
    np_labels = np.concatenate((np_labels, np_nlabels_1, np_nlabels_2), axis=None)

# %%
np_labels.shape
# Out:
# (425,)

# %%
np.save(f'/content/drive/MyDrive/TFM/Google_Colab/CWRU/CRWU_Javi/datasets_finales/dataset_labels_{filas}', np_labels)
